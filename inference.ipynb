# %% [markdown]
# # 🐾 Animal Social Behavior — Inference
#
# Load a pretrained model from HuggingFace and run behavior inference on your own videos.
#
# **Models:** [yiheng266/animal-social-models](https://huggingface.co/yiheng266/animal-social-models)

# %%
# @title 1. Install dependencies
# !pip install -q torch torchvision transformers decord gradio huggingface_hub pandas Pillow scikit-learn

# %%
# @title 2. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# @title 3. Clone repo
# !git clone https://github.com/yiheng266/open-animal-behavior.git
# %cd open-animal-behavior

# %%
# @title 4. Set paths and launch GUI

# ==================== 👇 修改這裡 👇 ====================
VIDEO_DIR  = "/content/drive/My Drive/videos/"        # 你的影片資料夾
OUTPUT_DIR = "/content/drive/My Drive/results/"       # 結果儲存位置
# ==================== 👆 修改以上即可 👆 ====================

import gui_inference
gui_inference.DEFAULT_VIDEO_DIR  = VIDEO_DIR
gui_inference.DEFAULT_OUTPUT_DIR = OUTPUT_DIR
gui_inference.demo.launch(share=True)
