# %% [markdown]
# # 🏋️ Animal Social Behavior — Training
#
# Fine-tune a pretrained model on your own labeled videos.
#
# **Pretrained models:** [yiheng266/animal-social-models](https://huggingface.co/yiheng266/animal-social-models)

# %%
# @title 1. Install dependencies
# !pip install -q torch torchvision transformers decord gradio huggingface_hub pandas Pillow scikit-learn

# %%
# @title 2. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# @title 3. Clone repo
# !git clone https://github.com/yiheng266/open-animal-behavior.git
# %cd open-animal-behavior

# %%
# @title 4. Set paths and launch GUI

# ==================== 👇 修改這裡 👇 ====================
VIDEO_DIR  = "/content/drive/My Drive/videos/train/"         # 訓練影片資料夾
LABEL_DIR  = "/content/drive/My Drive/labels/train/"         # one-hot CSV 標籤資料夾
OUTPUT_DIR = "/content/drive/My Drive/trained_models/"       # 模型儲存位置
# ==================== 👆 修改以上即可 👆 ====================

import gui_training
gui_training.DEFAULT_VIDEO_DIR  = VIDEO_DIR
gui_training.DEFAULT_LABEL_DIR  = LABEL_DIR
gui_training.DEFAULT_OUTPUT_DIR = OUTPUT_DIR
gui_training.demo.launch(share=True)
